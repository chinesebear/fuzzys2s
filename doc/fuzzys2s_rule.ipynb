# %% [markdown]
# ## plot graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import matplotlib.font_manager as fm
fm.fontManager.addfont('/usr/share/fonts/truetype/times.ttf')
plt.rc('font',family='Times New Roman')
import numpy as np

euconst_data = [
    [55.45,37.72,69.88], # transformer
    [55.50,46.73,72.45],
    [55.61,49.64,79.12], # rule 3
    [55.60,48.25,78.21],
    [55.58,48.27,78.75],
    [55.59,48.12,78.66],
    [55.58,48.10,78.53],
    [55.57,48.10,78.67], 
    [55.55,48.07,78.00], 
    [55.55,48.05,78.37]]

samsum_data = [
    [30.16,6.03,25.70], # transformer
    [33.49,8.07,26.82] ,
    [35.13,13.26,28.25] , # rule 3
    [34.42,12.77,28.27] ,
    [34.19,12.59,28.28] ,
    [34.18,12.75,27.88] ,
    [34.15,12.72,27.44] ,
    [34.15,12.70,27.24] ,
    [34.13,12.74,27.24] ,
    [34.14,12.64,27.22] ]

hs_data=[
    [44.67,70.82,70.44], # transformer
    [46.70,71.20,72.84],
    [48.89,72.14,76.15], # rule 3
    [48.88,72.10,76.25], 
    [48.48,72.03,76.16],
    [48.38,71.82,76.00],
    [48.35,71.89,75.57],
    [48.32,71.88,75.55],
    [48.30,71.87,75.13],
    [48.32,71.33,75.10]]


rule_data = np.arange(1, 11, 1)
hs_data = np.array(hs_data)
euconst_data = np.array(euconst_data)
samsum_data = np.array(samsum_data)

f, axes = plt.subplots(3, 3, figsize=(15,15), dpi=300)

## 第一行
sub_graph = axes[0][0]
sub_graph.plot(rule_data, euconst_data[:, 0], label='EUconst', color='r')
sub_graph.scatter(rule_data, euconst_data[:, 0], alpha=.9, color='r')
sub_graph.set_title("Translation on EUconst")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("ACC")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(55.4,55.7)
# sub_graph.legend()

sub_graph = axes[0][1]
sub_graph.plot(rule_data, euconst_data[:, 1], label='EUconst', color='r')
sub_graph.scatter(rule_data, euconst_data[:, 1], alpha=.9, color='r')
sub_graph.set_title("Translation on EUconst")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("BLEU")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(35,55)
# sub_graph.legend()

sub_graph = axes[0][2]
sub_graph.plot(rule_data, euconst_data[:, 2], label='EUconst', color='r')
sub_graph.scatter(rule_data, euconst_data[:, 2], alpha=.9, color='r')
sub_graph.set_title("Translation on EUconst")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("METEOR")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(65,85)
# sub_graph.legend()

## 第二行
sub_graph = axes[1][0]
sub_graph.plot(rule_data, samsum_data[:, 0], label='SAMSum',color='g')
sub_graph.scatter(rule_data, samsum_data[:, 0], alpha=.9, color='g')
sub_graph.set_title("Summary Generation on SAMSum")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("R1")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(28,38)
# sub_graph.legend()


sub_graph = axes[1][1]
sub_graph.plot(rule_data, samsum_data[:, 1], label='SAMSum',color='g')
sub_graph.scatter(rule_data, samsum_data[:, 1], alpha=.9, color='g')
sub_graph.set_title("Summary Generation on SAMSum")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("R2")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(4,16)
# sub_graph.legend()

sub_graph = axes[1][2]
sub_graph.plot(rule_data, samsum_data[:, 2], label='SAMSum',color='g')
sub_graph.scatter(rule_data, samsum_data[:, 2], alpha=.9, color='g')
sub_graph.set_title("Summary Generation on SAMSum")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("RL")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(24,30)
# sub_graph.legend()

## 第三行
sub_graph = axes[2][0]
sub_graph.plot(rule_data, hs_data[:, 0], label='HS')
sub_graph.scatter(rule_data, hs_data[:, 0], alpha=.9)
sub_graph.set_title("Code Generation on HS")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("ACC")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(44,50)
# sub_graph.legend()

sub_graph = axes[2][1]
sub_graph.plot(rule_data, hs_data[:, 1], label='HS')
sub_graph.scatter(rule_data, hs_data[:, 1], alpha=.9)
sub_graph.set_title("Code Generation on HS")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("BLEU")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(70,73)
# sub_graph.legend()

sub_graph = axes[2][2]
sub_graph.plot(rule_data, hs_data[:, 2], label='HS')
sub_graph.scatter(rule_data, hs_data[:, 2], alpha=.9)
sub_graph.set_title("Code Generation on HS")
sub_graph.set_xlabel("Rule")
sub_graph.set_ylabel("METEOR")
sub_graph.set_xlim(0,11)
sub_graph.xaxis.set_major_locator(MaxNLocator(integer=True))
sub_graph.set_ylim(70,80)
# sub_graph.legend()

plt.rcParams.update({'font.size': 16})
# plt.subplots_adjust(wspace =0.4, hspace =0.3)#调整子图间距 (0,1)
plt.tight_layout()#调整整体空白
plt.savefig("fuzzys2s-rule.svg", format = "svg")
plt.savefig("fuzzys2s-rule.jpg", format = "jpg")
plt.show()
